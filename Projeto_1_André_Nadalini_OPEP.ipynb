# %% [markdown]
# Sobre a OPEP:
#
# Criada em 14 de setembro de 1960, a Organização dos Países Exportadores de Petróleo (OPEP) é uma organização intergovernamental, que tem como objetivo a centralização da elaboração das políticas sobre produção e venda do petróleo dos países integrantes.
#
# Atualmente, os países membros da OPEP são: Argélia, Angola, Equador, Irã, Iraque, Kuwait, Líbia, Nigéria, Catar, Arábia Saudita, Emirados Árabes Unidos e Venezuela. A Indonésia suspendeu a sua adesão em janeiro de 2009. A sede da OPEP está localizada em Viena, capital da Áustria.

# %% [markdown]
# Estudo sobre o impacto do petróleo:
#
# O trecho abaixo, retirado de um estudo sobre o impacto do pré-sal no Brasil, mostra algumas consequências de uma economia baseada principalmente no petróleo.
#
# "A energia é a base da sociedade industrializada e o petróleo, dentre todas as fontes, vem se mostrando ao longo do tempo, a maior e mais problemática devido ao seu papel central, ao seu caráter estratégico, a sua distribuição geográfica, ao padrão recorrente de crises em seu fornecimento e finalmente a irresistível cobiça de tomar posse de suas recompensas (YERGIN, 2010, p.886).
#
# Assim, é natural concluir que países com grandes reservas petrolíferas devam tender a níveis de crescimento e desenvolvimento mais elevados do que outros que não o possuem. No entanto, experiências mundiais, tem demonstrado exatamente o inverso, ou seja, o excesso de petróleo associado com altos níveis de empobrecimento e subdesenvolvimento.
#
# A atividade petrolífera em países tão diversos como, por exemplo, Angola, Arábia Saudita, Argélia, Congo Equador, Irã, Iraque, Kuwait, Líbia Peru, Qatar e Trinidad e Tobago, fez com que o padrão de vida de suas populações, que já era precário, ficasse ainda pior. A Venezuela tinha a maior renda per capita da América do Sul antes de um enorme impulso do petróleo ocorrido a partir de 1970, e no início da década de 2000, sofria de violência crônica e tinha uma renda per capita menor do que nos anos de 1960 (SHAH, 2007)
#
# A Arábia Saudita é um dos maiores produtores de petróleo do mundo, com relação à expectativa de vida, educação e renda, fica atrás da Romênia e da Tailândia. A Nigéria, apesar dos bilhões de dólares em óleo que corre sob seu território, tem seu Índice de Desenvolvimento Humano entre os dez piores do mundo (SHAH, 2007, p.109).
#
# As organizações de ajuda, os ativistas e até mesmo o Banco Mundial já detectaram a seguinte tendência: o petróleo é descoberto em algum país remoto ou subdesenvolvido. Nesse momento, as empresas surgem e normalmente arranjam barganhas injustas com burocratas esperançosos e inexperientes em negociar com multinacionais. Ao se iniciar o custoso processo de criar infraestrutura para extração, todos são excluídos do jogo, com exceção das elites sociais.
#
# Quando o petróleo começa a ser bombeado, essas elites adquirem enormes riquezas e consequentemente mais poder. Os governos aumentam os gastos públicos em projetos ambiciosos para posteriormente descobrir que os preços voláteis do petróleo inviabilizaram seus planos. Para remediar a falta de verbas, muitos fazem enormes empréstimos com o óleo cru, como fiador, e assim os países ficam sufocados em dívidas. Por outro lado, atividades mais sustentáveis como a pesca e o cultivo de grãos, entre outras, perdem atratividade, pois torna-se mais fácil importar do que produzir.
#
# Segundo STIGLITZ (2003, p. 106) o influxo de capital leva a uma valorização da moeda, barateando as importações e encarecendo as exportações, isso pode em alguns casos impedir o desenvolvimento, por meio de um mecanismo denominado “doença holandesa” (Dutch Disease). O nome deriva da experiência da Holanda após a descoberta de gás no norte. As vendas de gás natural fizeram com que a moeda holandesa, subisse, prejudicando seriamente os outros setores de exportação do país."
#
# http://www.eumed.net/cursecon/ecolat/br/15/doenza-holandesa.html:

# %% [markdown]
# Sobre a Doença holandesa:
#
#
# O termo “doença holandesa” (Dutch disease) foi mencionado pela primeira vez na revista semanal inglesa The Economist, em 1977, para descrever os efeitos nocivos sobre a indústria holandesa derivados da descoberta de grandes reservas de gás natural no Mar do Norte, nos anos 1960-70. A entrada de divisas na Holanda ocasionada pela exportação de gás natural provocou a valorização da moeda holandesa (florim), reduzindo a competitividade de suas indústrias e, portanto, causando a desindustrialização.
#
# Assim, inicialmente, pode-se definir doença holandesa como a especialização produtiva de um país, quer ele possua ou não certo grau de industrialização, na produção de produtos intensivos em recursos naturais. Ao gerar vantagens competitivas derivadas de rendas ricardianas, tal especialização modifica a pauta de exportações e, portanto, gera aumento das receitas em moeda estrangeira. Na ausência de uma políticacambial que opere de forma a compensar esse efeito, ocorre sobreapreciação da taxa de câmbio real. Essa reduz a competitividade da indústria doméstica vis a vis à do resto do mundo, tendo como consequência a retração da produção e/ou exportação de bens comercializáveis mais intensivos em tecnologia e com maior valor agregado. Ou seja, ocorre uma espécie de “reprimarização ou especialização regressiva” da pauta de exportação e da estrutura produtiva (Bresser-Pereira, 2008).
#
# https://revistas.fee.tche.br/index.php/indicadores/article/viewFile/2951/3214

# %% [markdown]
# Levando-se em conta o estudo citado acima e outros e a teoria da Doença holandesa, pode-se levantar algumas perguntas e hipóteses.
#
# Perguntas:
#    A adesão à organização impacta na produção e exportação de petróleo? E na relevância que um país dá ao setor em suas importações?
#
#    Considerando a grande produção e enorme foco na exportação de petróleo recorrente nos países membros do grupo, quais são as consequências socioeconômicas para o país?

# %% [markdown]
# Hipóteses:
#
# Por conta da enorme importancia e influência do grupo na produção e venda de petróleo e visto a grande dependência que o petróleo pode causar em uma economia, cria-se a hipótese de que um país, ao entrar para tal grupo, aumente consideravelmente sua produçao e venda com relação a países que não se encontram no mesmo, criando uma economia muito baseada na exploração e exportação do óleo.
#
# Visto os estudos mencionados e a teoria da Doença holandesa, presume-se que os países membros da OPEP possuam:
# uma taxa cambial alta;
# um IDH baixo;
# uma alta desigualdade social;
# uma baixa renda per capta.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import math as math
from scipy import stats
import matplotlib.pyplot as plt
import os
meu_diretorio = "/Users\W10\Documents\Insper\Semestre 2\Ciencia dos dados\Projeto 1 OPEP"
os.chdir(meu_diretorio)

# %%
#Importando planilha da Produção de petróleo de cada país em cada ano (por tonelada):

prodpetrol = pd.read_excel('oil_production_total.xlsx')
prodpetrol=prodpetrol.set_index('country')
#prodpetrol=prodpetrol.loc[:,[1965, 1980,2000,2015]]

#Definindo os membros da OPEP:
paises=['Algeria','Angola','Ecuador','Iran','Iraq','Kuwait','Libya','Nigeria','Qatar','Saudi Arabia','United Arab Emirates','Venezuela']
prodpetrol["OPEP"]=0
prodpetrol.loc[paises,'OPEP']=1
prodpetrol.OPEP = prodpetrol.OPEP.astype('category')
prodpetrol.OPEP.cat.categories = ("Não pertence", "Membro")

#Definindo os grandes produtores de petróleo que não estão na OPEP (gpd)
gpd=['China', 'Canada', 'Brazil', 'Norway','Kazakhstan','Mexico']

prodpetrol["Grande produtor de petróleo"]=0
prodpetrol.loc[paises,'Grande produtor de petróleo']=1
prodpetrol.loc[ gpd,'Grande produtor de petróleo']=1
prodpetrol["Grande produtor de petróleo"] = prodpetrol["Grande produtor de petróleo"].astype('category')
prodpetrol["Grande produtor de petróleo"].cat.categories = ("Não", "Sim")


prodpetrol.head()
# Out:
#                   1965        1966        1967        1968        1969  \
# country
# Algeria     26500000.0  33900000.0  39100000.0  42900000.0  44800000.0
# Angola        655000.0    631000.0    537000.0    750000.0   2460000.0
# Argentina   13800000.0  14600000.0  16000000.0  17500000.0  18100000.0
# Australia     346000.0    445000.0   1040000.0   1930000.0   2230000.0
# Azerbaijan         NaN         NaN         NaN         NaN         NaN
#
#                   1970        1971        1972        1973        1974  \
# country
# Algeria     48200000.0  37100000.0  50100000.0  50900000.0  47400000.0
# Angola       5070000.0   5720000.0   7060000.0   8180000.0   8540000.0
# Argentina   20000000.0  21600000.0  22200000.0  21600000.0  21100000.0
# Australia    8700000.0  15300000.0  16300000.0  20400000.0  20200000.0
# Azerbaijan         NaN         NaN         NaN         NaN         NaN
#
#                        ...                     2009        2010        2011  \
# country                ...
# Algeria                ...               77200000.0  73800000.0  71700000.0
# Angola                 ...               87600000.0  90500000.0  83800000.0
# Argentina              ...               34000000.0  33300000.0  30900000.0
# Australia              ...               22400000.0  24500000.0  21500000.0
# Azerbaijan             ...               50400000.0  50800000.0  45600000.0
#
#                 2012      2013      2014      2015      2016          OPEP  \
# country
# Algeria     67200000  64800000  68800000  67200000  68500000        Membro
# Angola      86900000  87300000  83000000  88700000  87900000        Membro
# Argentina   31100000  30500000  29900000  29800000  28800000  Não pertence
# Australia   21400000  17800000  19100000  17400000  15500000  Não pertence
# Azerbaijan  43400000  43500000  42100000  41600000  41000000  Não pertence
#
#             Grande produtor de petróleo
# country
# Algeria                             Sim
# Angola                              Sim
# Argentina                           Não
# Australia                           Não
# Azerbaijan                          Não
#
# [5 rows x 54 columns]

# %%
#Importando planilha das rezervas de petróleo conhecidas em cada país:
reserva = pd.read_excel('oil_proved_reserves_total.xlsx')
reserva=reserva.set_index('country')

#Separando a OPEP e o gpd:
#reserva[1965]='NaN'
reserva["OPEP"]=0
reserva.loc[paises,"OPEP"]=1
reserva.OPEP = reserva.OPEP.astype('category')
reserva.OPEP.cat.categories = ("Não pertence", "Membro")
reserva["Grande produtor de petróleo"]=0
reserva.loc[paises,'Grande produtor de petróleo']=1
reserva.loc[ gpd,'Grande produtor de petróleo']=1
reserva["Grande produtor de petróleo"] = reserva["Grande produtor de petróleo"].astype('category')
reserva["Grande produtor de petróleo"].cat.categories = ("Não", "Sim")

reserva.head()
# Out:
#                     1980          1981          1982          1983  \
# country
# Algeria     1.120000e+09  1.100000e+09  1.290000e+09  1.260000e+09
# Angola      1.880000e+08  1.510000e+08  1.990000e+08  2.340000e+08
# Argentina   3.350000e+08  2.960000e+08  2.660000e+08  3.340000e+08
# Australia   2.900000e+08  3.570000e+08  4.000000e+08  3.400000e+08
# Azerbaijan           NaN           NaN           NaN           NaN
#
#                     1984          1985          1986          1987  \
# country
# Algeria     1.230000e+09  1.200000e+09  1.200000e+09  1.170000e+09
# Angola      2.930000e+08  2.750000e+08  1.910000e+08  2.730000e+08
# Argentina   3.200000e+08  3.060000e+08  3.050000e+08  3.060000e+08
# Australia   3.490000e+08  3.350000e+08  3.920000e+08  3.960000e+08
# Azerbaijan           NaN           NaN           NaN           NaN
#
#                     1988          1989             ...               \
# country                                            ...
# Algeria     1.250000e+09  1.260000e+09             ...
# Angola      2.730000e+08  2.830000e+08             ...
# Argentina   3.110000e+08  2.960000e+08             ...
# Australia   4.350000e+08  4.230000e+08             ...
# Azerbaijan           NaN           NaN             ...
#
#                     2009          2010          2011        2012        2013  \
# country
# Algeria     1.660000e+09  1.660000e+09  1.660000e+09  1660000000  1660000000
# Angola      1.300000e+09  1.300000e+09  1.240000e+09  1730000000  1730000000
# Argentina   3.430000e+08  3.440000e+08  3.440000e+08   321000000   318000000
# Australia   5.540000e+08  5.230000e+08  5.280000e+08   535000000   540000000
# Azerbaijan  9.550000e+08  9.550000e+08  9.550000e+08   955000000   955000000
#
#                   2014        2015        2016          OPEP  \
# country
# Algeria     1660000000  1660000000  1660000000        Membro
# Angola      1720000000  1610000000  1580000000        Membro
# Argentina    325000000   327000000   327000000  Não pertence
# Australia    543000000   543000000   543000000  Não pertence
# Azerbaijan   955000000   955000000   955000000  Não pertence
#
#             Grande produtor de petróleo
# country
# Algeria                             Sim
# Angola                              Sim
# Argentina                           Não
# Australia                           Não
# Azerbaijan                          Não
#
# [5 rows x 39 columns]

# %%
#importando planilha da taxa do combustível nas mercadorias exportadas:
#Txpib= % da mercadoria exportada
txpib = pd.read_excel('tx_val_fuel_zs_un.xlsx')
txpib=txpib.set_index('country')

#Separando a OPEP e o gpd:
txpib["OPEP"]=0
txpib.loc[paises,"OPEP"]=1
txpib.OPEP = txpib.OPEP.astype('category')
txpib.OPEP.cat.categories = ("Não pertence", "Membro")
txpib["Grande produtor de petróleo"]=0
txpib.loc[paises,'Grande produtor de petróleo']=1
txpib.loc[ gpd,'Grande produtor de petróleo']=1
txpib["Grande produtor de petróleo"] = txpib["Grande produtor de petróleo"].astype('category')
txpib["Grande produtor de petróleo"].cat.categories = ("Não", "Sim")

txpib.head()
# Out:
#              1962  1963  1964  1965  1966  1967  1968   1969  1970  1971  \
# country
# Afghanistan   NaN   NaN   NaN   NaN   NaN  4.41  12.6  14.90  16.9  14.6
# Albania       NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN
# Algeria       NaN   NaN   NaN   NaN  59.3   NaN  71.0  67.60  70.2  74.9
# Andorra       NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN
# Angola       3.04   NaN   NaN   NaN   NaN   NaN   NaN   7.18  13.4  19.9
#
#                         ...                   2011     2012    2013    2014  \
# country                 ...
# Afghanistan             ...                    NaN      NaN     NaN     NaN
# Albania                 ...               21.20000  26.6000  31.000   1.570
# Algeria                 ...               97.20000  97.1000  96.700  95.800
# Andorra                 ...                0.00308   0.0986   0.128   0.123
# Angola                  ...               96.60000  97.2000  96.700  96.200
#
#                2015     2016     2017   2018          OPEP  \
# country
# Afghanistan   3.450      NaN      NaN    NaN  Não pertence
# Albania       8.810  11.2000   0.8350  1.660  Não pertence
# Algeria      94.300  94.0000  94.5000    NaN        Membro
# Andorra       0.046   0.0208   0.0097  0.014  Não pertence
# Angola       95.000      NaN      NaN    NaN        Membro
#
#              Grande produtor de petróleo
# country
# Afghanistan                          Não
# Albania                              Não
# Algeria                              Sim
# Andorra                              Não
# Angola                               Sim
#
# [5 rows x 59 columns]

# %%
indx_gini=pd.read_excel('inequality_index_gini.xlsx')
indx_gini=indx_gini.set_index('country')
#indx_gini=indx_gini.loc[:,[1965,1980,2000,2015]]
indx_gini['OPEP']=0
indx_gini.loc[paises,"OPEP"]=1
indx_gini.OPEP=indx_gini.OPEP.astype('category')
indx_gini.OPEP.cat.categories= ("Nâo pertence", "Membro")
indx_gini['Grande produtor de petróleo']=0
indx_gini.loc[paises,'Grande produtor de petróleo']=1
indx_gini.loc[ gpd,'Grande produtor de petróleo']=1
indx_gini["Grande produtor de petróleo"] = indx_gini["Grande produtor de petróleo"].astype('category')
indx_gini["Grande produtor de petróleo"].cat.categories = ("Não", "Sim")

#indx_gini=indx_gini[['OPEP',1965,1980,2000,2015]]
indx_gini.head()
# Out:
#            1979  1980  1981  1982  1983  1984  1985  1986  1987  1988  \
# country
# Albania     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Algeria     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  40.2
# Angola      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Argentina   NaN  40.8   NaN   NaN   NaN   NaN   NaN  42.8  45.3   NaN
# Armenia     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                       ...               2010  2011  2012  2013  2014  2015  \
# country               ...
# Albania               ...                NaN   NaN  29.0   NaN   NaN   NaN
# Algeria               ...                NaN  27.6   NaN   NaN   NaN   NaN
# Angola                ...                NaN   NaN   NaN   NaN   NaN   NaN
# Argentina             ...               43.0  42.3  41.2  41.0  41.4   NaN
# Armenia               ...               30.0  29.4  29.6  30.6  31.5  32.4
#
#            2016  2017          OPEP  Grande produtor de petróleo
# country
# Albania     NaN   NaN  Nâo pertence                          Não
# Algeria     NaN   NaN        Membro                          Sim
# Angola      NaN   NaN        Membro                          Sim
# Argentina  42.4   NaN  Nâo pertence                          Não
# Armenia    32.5   NaN  Nâo pertence                          Não
#
# [5 rows x 41 columns]

# %%
taxa_cambio=pd.read_excel('taxa_de_cambio.xlsx')
taxa_cambio=taxa_cambio.set_index('country')
#taxa_cambio=taxa_cambio.loc[:,[1965,1980,2000,2015]]
taxa_cambio['OPEP']=0
taxa_cambio.loc[paises,"OPEP"]=1
taxa_cambio.OPEP=taxa_cambio.OPEP.astype('category')
taxa_cambio.OPEP.cat.categories= ("Nâo pertence", "Membro")
taxa_cambio["Grande produtor de petróleo"]=0
taxa_cambio.loc[paises,'Grande produtor de petróleo']=1
taxa_cambio.loc[ gpd,'Grande produtor de petróleo']=1
taxa_cambio["Grande produtor de petróleo"] = taxa_cambio["Grande produtor de petróleo"].astype('category')
taxa_cambio["Grande produtor de petróleo"].cat.categories = ("Não", "Sim")

#taxa_cambio=taxa_cambio[['OPEP',1965,1980,2000,2015]]
taxa_cambio.head()
# Out:
#                        1960    1961    1962    1963    1964    1965    1966  \
# country
# Afghanistan          194.00  194.00  194.00  396.00  436.00  436.00  436.00
# Albania                 NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Algeria                4.94    4.94    4.94    4.94    4.94    4.94    4.94
# Angola                  NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Antigua and Barbuda    1.71    1.71    1.71    1.71    1.71    1.71    1.71
#
#                        1967    1968    1969             ...               \
# country                                                 ...
# Afghanistan          436.00  436.00  436.00             ...
# Albania                 NaN     NaN     NaN             ...
# Algeria                4.94    4.94    4.94             ...
# Angola                  NaN     NaN     NaN             ...
# Antigua and Barbuda    1.76    2.00    2.00             ...
#
#                      2008  2009   2010   2011   2012   2013  2014   2015  \
# country
# Afghanistan          50.2  50.3   46.5   46.7   50.9   55.4   NaN    NaN
# Albania              83.9  95.0  104.0  101.0  108.0  106.0   NaN    NaN
# Algeria              64.6  72.6   74.4   72.9   77.5   79.4  80.6  101.0
# Angola               75.0  79.3   91.9   93.9   95.5   96.5   NaN    NaN
# Antigua and Barbuda   2.7   2.7    2.7    2.7    2.7    2.7   NaN    NaN
#
#                              OPEP  Grande produtor de petróleo
# country
# Afghanistan          Nâo pertence                          Não
# Albania              Nâo pertence                          Não
# Algeria                    Membro                          Sim
# Angola                     Membro                          Sim
# Antigua and Barbuda  Nâo pertence                          Não
#
# [5 rows x 58 columns]

# %%
idh=pd.read_excel('hdi_human_development_index.xlsx')
idh=idh.set_index('country')
#idh=idh.loc[:,[1965,1980,2000,2015]]
idh['OPEP']=0
idh.loc[paises,"OPEP"]=1
idh.OPEP=idh.OPEP.astype('category')
idh.OPEP.cat.categories= ("Nâo pertence", "Membro")
idh["Grande produtor de petróleo"]=0
idh.loc[paises,'Grande produtor de petróleo']=1
idh.loc[ gpd,'Grande produtor de petróleo']=1
idh["Grande produtor de petróleo"] = idh["Grande produtor de petróleo"].astype('category')
idh["Grande produtor de petróleo"].cat.categories = ("Não", "Sim")

#idh=idh[['OPEP',1965,1980,2000,2015]]
idh.head()
# Out:
#               1990   1991   1992   1993   1994   1995   1996   1997   1998  \
# country
# Afghanistan  0.295  0.300  0.309  0.305  0.300  0.324  0.328  0.332  0.335
# Albania      0.635  0.618  0.603  0.608  0.616  0.628  0.637  0.636  0.646
# Algeria      0.577  0.581  0.587  0.591  0.595  0.600  0.609  0.617  0.627
# Andorra        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Angola         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#               1999             ...                2008   2009   2010   2011  \
# country                        ...
# Afghanistan  0.338             ...               0.434  0.448  0.454  0.463
# Albania      0.656             ...               0.721  0.725  0.738  0.752
# Algeria      0.636             ...               0.705  0.714  0.724  0.732
# Andorra        NaN             ...                 NaN    NaN  0.819  0.819
# Angola       0.382             ...               0.480  0.488  0.495  0.508
#
#               2012   2013   2014   2015          OPEP  \
# country
# Afghanistan  0.470  0.476  0.479  0.479  Nâo pertence
# Albania      0.759  0.761  0.762  0.764  Nâo pertence
# Algeria      0.737  0.741  0.743  0.745        Membro
# Andorra      0.843  0.850  0.857  0.858  Nâo pertence
# Angola       0.523  0.527  0.531  0.533        Membro
#
#              Grande produtor de petróleo
# country
# Afghanistan                          Não
# Albania                              Não
# Algeria                              Sim
# Andorra                              Não
# Angola                               Sim
#
# [5 rows x 28 columns]

# %%
#Função que retorna um join dos dataframes feitos anteriormente em função do ano:
def join(ano):
    result=pd.DataFrame()
    result['country']=(prodpetrol.index)
    result=result.set_index("country")
    result['OPEP']=0
    result.loc[paises]=1
    result.OPEP = result.OPEP.astype('category')
    result.OPEP.cat.categories = ("Não pertence", "Membro")
    result["Grande produtor de petróleo"]=0
    result.loc[paises,'Grande produtor de petróleo']=1
    result.loc[ gpd,'Grande produtor de petróleo']=1
    result["Grande produtor de petróleo"] = prodpetrol["Grande produtor de petróleo"].astype('category')
    result["Grande produtor de petróleo"].cat.categories = ("Não", "Sim")

    result['Produção de petróleo (toneladas)']=prodpetrol[ano]
    result['Reserva acessível (equivalente em toneladas)']=reserva[ano]
    result['% do combustível na exportação de mercadorias']=txpib[ano]
    result['Taxa de câmbio']=taxa_cambio[ano]
    result['Coeficiente de Gini']=indx_gini[ano]
    result['IDH']=idh[ano]
    return result

# %%
#Gráfico do crescimento temporal da produção:
prodopep=prodpetrol.loc[paises,:]
prodoutros=prodpetrol.loc[prodpetrol["Grande produtor de petróleo"]=='Não',:]
prodgpd=prodpetrol.loc[gpd,:]
anos=[]
i=1965
while i < 2017:
    anos.append(i)
    i+=1
plt.plot(anos,prodopep.mean(), label='OPEP')
#plt.plot(anos,prodopep.mean())
plt.plot(anos,prodgpd.mean(), label='Gpd')
#plt.plot(anos,prodopep.median())
#plt.plot(anos,prodoutros.median())
plt.plot(anos,prodoutros.mean(), label= 'outros')

plt.grid(True)
plt.title('Produção de petróleo ao longo dos anos')
plt.xlabel('Ano')
plt.ylabel('Média da produção (em toneladas)')
plt.legend()
plt.show()

#Crescimento da produção:
cprodgpd=(prodgpd[2014].mean()-prodgpd[1990].mean())/prodgpd[1990].mean()*100
cprodopep=(prodopep[2014].mean()-prodopep[1990].mean())/prodopep[1990].mean()*100
cprodoutros=(prodoutros[2014].mean()-prodoutros[1990].mean())/prodoutros[1990].mean()*100

print('Crescimento da média da produção de grandes produtores de petróleo entre 1990 e 2014:{0}%'.format(cprodgpd))
print('Crescimento da média da produção de membros da OPEP entre 1990 e 2014:{0}%'.format(cprodopep))
print('Crescimento da média da produção de outros entre 1990 e 2014:{0}%'.format(cprodoutros))
# Out:
# Crescimento da média da produção de grandes produtores de petróleo entre 1990 e 2014:63.26767091541136%
# Crescimento da média da produção de membros da OPEP entre 1990 e 2014:49.07335574519437%
# Crescimento da média da produção de outros entre 1990 e 2014:-4.198195737268913%

# %% [markdown]
# Análise do gráfico:
#
# O gráfico acima mostra a média da produção de petróleo da OPEP (em azul), a média da produção do Gpd (Grandes produtores de petróleo) (em laranja) e a média da produção do restante dos países disponíveis no dataframe. Assim, pode-se analisar o crescimento temporal da produção de petróleo no mundo. Nota-se que nos anos iniciais, a média da produção dos países membros da OPEP é consideravelmente maior do que o restante, o que indica que, na época da criação do grupo (1960), este era responsável por uma enorme parte da produção mundial, indicando, assim, um dos principais objetivos da criação do grupo: controlar o preço do petróleo no mercado mundial (já que controla grande parte da oferta).
#
# No entanto, pode-se ver que o maior aumento na produção não aconteceu na OPEP, mas sim em países em desenvolvimento como China, Brasil e México (curva laranja) que descobriram  reservas mais recentemente -63% de crescimento contra 49% da OPEP. Assim, ao realizar-se a análise de anos mais recentes, vê-se que a produção média do Gpd (países com grande produção de petróleo fora da OPEP) é muito próxima à da OPEP.
#
# É interessante notar também que no final da década de 70 até meados de 80, a média da produção da OPEP cai consideravelmente, fenômeno que pode ser relacionado ao segundo choque do petróleo que se instaurou após a Revolução iraniana(1979),desorganizando completamente o setor econômico iraniano, e sucedido pela Guerra Irã-Iraque (1980-1988) que afetou significativamente a produção dos dois países em guerra (ambos pertencentes ao bloco).

# %%
#Gráfico da relevância do petróleo nas exportações dos países ao longo do tempo:
i=1970
anos=[]
while i < 2017:
    anos.append(i)
    i+=1
txpibopep=txpib.loc[paises,anos]
txpiboutros=txpib.loc[txpib["Grande produtor de petróleo"]=='Não',anos]
txpibgpd=txpib.loc[gpd,anos]

plt.plot(anos,txpibopep.mean(),label='OPEP')
plt.plot(anos,txpibgpd.mean(),label='Gpd')
plt.plot(anos,txpiboutros.mean(),label='Outros')
#plt.plot(anos,txpibopep.median())
#plt.plot(anos,txpiboutros.median())

plt.grid(True)
plt.title('% do combustível nas mercadorias exportadas ao longo dos anos')
plt.xlabel('Ano')
plt.ylabel('% do combustível nas exportações')
plt.legend()
plt.show()

# %% [markdown]
# Análise do Gráfico:
#
# O gráfico acima mostra a % do combustível na exportação das mercadorias, ou seja, mostra a relevância do petróleo para a balança comercial e economia do grupo.
#
# O contraste dos dados é claro. Pode-se observar que o petróleo representa, para os membros da OPEP, um peso enorme em suas economia, deixando-as muito mais vulneráveis a esse combústivel. O mesmo não acontece com o Gpd nem com o restante dos países, ou seja, os países membros da OPEP são extremamente mais dependentes do petróleo do que o restante do mundo, o que pode ser um sério problema frente a uma possível diminuição na demanda do mesmo. Dessa forma, pode-se ver que é de grande interesse dos membros da OPEP que o mundo continue utilizando combustíveis fósseis como principal fonte energética.
#
# Observa-se que os valores para os membros da OPEP não se alteram significativamente no período em questão, mostrando uma baixa preocupação com essa economia baseada principalmente no petróleo, não se observa nenhuma mudança significativa em direção à uma economia mais variada, menos focada na exportação dessa comoditty.

# %%
#Gráfico do IDH dos países ao longo do tempo:
i=1990
anos=[]
while i < 2015:
    anos.append(i)
    i+=1
idhopep=idh.loc[paises,anos]
idhgpd=idh.loc[gpd,anos]
idhoutros=idh.loc[idh["Grande produtor de petróleo"]=='Não',anos]
plt.plot(anos,idhopep.mean(),label='OPEP')
plt.plot(anos,idhgpd.mean(),label='Gpd')
plt.plot(anos,idhoutros.mean(),label='Outros')
#plt.plot(anos,idhopep.median())
#plt.plot(anos,idhoutros.median())

plt.grid(True)
plt.title('IDH dos membros da OPEP e do resto do mundo no tempo')
plt.xlabel('Ano')
plt.ylabel('IDH')
plt.legend()

crescgpd=(idhgpd[2014].mean()-idhgpd[1990].mean())/idhgpd[1990].mean()*100
crescopep=(idhopep[2014].mean()-idhopep[1990].mean())/idhopep[1990].mean()*100
crescoutros=(idhoutros[2014].mean()-idhoutros[1990].mean())/idhoutros[1990].mean()*100

print('Crescimento da média do IDH de grandes produtores de petróleo entre 1990 e 2014:{0}%'.format(crescgpd))
print('Crescimento da média do IDH de membros da OPEP entre 1990 e 2014:{0}%'.format(crescopep))
print('Crescimento da média do IDH de outros entre 1990 e 2014:{0}%'.format(crescoutros))

plt.show()
# Out:
# Crescimento da média do IDH de grandes produtores de petróleo entre 1990 e 2014:18.33092136999518%
# Crescimento da média do IDH de membros da OPEP entre 1990 e 2014:11.415525114155242%
# Crescimento da média do IDH de outros entre 1990 e 2014:18.18242573412504%

# %% [markdown]
# Análise do gráfico:
#
# O gráfico acima mostra as médias dos IDHs dos grupos ao longo do tempo. Ao analisá-lo, pode-se observar um crescimento no IDH nos três grupos, crescimento oriundo do desenvolvimento tecnológico, humano e econômico natural do capitalismo. No entanto, este desenvolvimento não aconteceu na mesma intensidade. Enquanto os Gdp e o restante do mundo tiveram um crescimento de 18% do IDH, a OPEP teve um crescimento de apenas 11%, apresentando também momentos de decaimento, se aproximando da média do restante do mundo e se afastando do Gdp.
#
# Dessa maneira, este gráfico mostra um desenvolvimento menos acelerados para os países do bloco, fenômeno que pode ser relacionado com a teoria da doença holandesa, que afirma que países a especialização produtiva de um país, seguida de uma apreciação cambial, reduzindo a competitividade de suas indústrias, causando a desindustrialização, que acaba afetando o desenvolvimento do país.

# %%
# Dataframe final de 1965:
join(2000).head()
# Out:
#                     OPEP Grande produtor de petróleo  \
# country
# Algeria           Membro                         Sim
# Angola            Membro                         Sim
# Argentina   Não pertence                         Não
# Australia   Não pertence                         Não
# Azerbaijan  Não pertence                         Não
#
#             Produção de petróleo (toneladas)  \
# country
# Algeria                           66800000.0
# Angola                            36900000.0
# Argentina                         41400000.0
# Australia                         37100000.0
# Azerbaijan                        14100000.0
#
#             Reserva acessível (equivalente em toneladas)  \
# country
# Algeria                                     1.540000e+09
# Angola                                      8.150000e+08
# Argentina                                   4.060000e+08
# Australia                                   6.740000e+08
# Azerbaijan                                  1.610000e+08
#
#             % do combustível na exportação de mercadorias  Taxa de câmbio  \
# country
# Algeria                                              97.2          75.300
# Angola                                                NaN          10.000
# Argentina                                            17.7           1.000
# Australia                                            21.9           1.720
# Azerbaijan                                           85.1           0.895
#
#             Coeficiente de Gini    IDH
# country
# Algeria                     NaN  0.644
# Angola                     52.0  0.391
# Argentina                  51.1  0.771
# Australia                   NaN  0.899
# Azerbaijan                  NaN  0.642

# %%
join(2008).describe()
# Out:
#        Produção de petróleo (toneladas)  \
# count                      4.800000e+01
# mean                       8.185583e+07
# std                        1.103229e+08
# min                        4.560000e+06
# 25%                        1.400000e+07
# 50%                        3.745000e+07
# 75%                        1.060000e+08
# max                        5.100000e+08
#
#        Reserva acessível (equivalente em toneladas)  \
# count                                  4.800000e+01
# mean                                   4.234894e+09
# std                                    7.825939e+09
# min                                    6.190000e+07
# 25%                                    2.147500e+08
# 50%                                    7.175000e+08
# 75%                                    3.712500e+09
# max                                    3.600000e+10
#
#        % do combustível na exportação de mercadorias  Taxa de câmbio  \
# count                                      42.000000       44.000000
# mean                                       52.318571      935.277500
# std                                        36.285142     3111.862087
# min                                         2.210000        0.269000
# 25%                                        17.325000        2.025000
# 50%                                        54.500000        5.535000
# 75%                                        91.625000      119.250000
# max                                        99.900000    16300.000000
#
#        Coeficiente de Gini        IDH
# count             20.00000  47.000000
# mean              39.80000   0.715894
# std                8.59302   0.132502
# min               25.20000   0.343000
# 25%               34.02500   0.649500
# 50%               40.95000   0.728000
# 75%               44.82500   0.791000
# max               55.40000   0.936000

# %%
#result1965=join(1965)
result1990=join(1990)
result2000=join(2000)
result2008=join(2008)
result2010=join(2010)
result2015=join(2015)
opep1990=join(1990).loc[paises,:]
opep2000=join(2000).loc[paises,:]
opep2008=join(2008).loc[paises,:]
opep2010=join(2010).loc[paises,:]
opep2015=join(2015).loc[paises,:]
outros1990=join(1990).loc[join(1990).OPEP=='Não pertence',:]
outros2000=join(2000).loc[join(2000).OPEP=='Não pertence',:]
outros2008=join(2000).loc[join(2000).OPEP=='Não pertence',:]
outros2010=join(2010).loc[join(2000).OPEP=='Não pertence',:]
outros2015=join(2015).loc[join(2000).OPEP=='Não pertence',:]

# %%
outros2000.describe()
# Out:
#        Produção de petróleo (toneladas)  \
# count                      3.500000e+01
# mean                       5.884800e+07
# std                        8.470419e+07
# min                        3.930000e+06
# 25%                        8.175000e+06
# 50%                        2.810000e+07
# 75%                        5.705000e+07
# max                        3.480000e+08
#
#        Reserva acessível (equivalente em toneladas)  \
# count                                  3.600000e+01
# mean                                   1.689169e+09
# std                                    4.732117e+09
# min                                    3.580000e+07
# 25%                                    1.237500e+08
# 50%                                    3.220000e+08
# 75%                                    7.257500e+08
# max                                    2.480000e+10
#
#        % do combustível na exportação de mercadorias  Taxa de câmbio  \
# count                                      31.000000       35.000000
# mean                                       34.860000      956.908314
# std                                        32.301331     2838.968464
# min                                         1.640000        0.385000
# 25%                                         7.480000        1.775000
# 50%                                        21.900000        8.280000
# 75%                                        64.600000      199.500000
# max                                        96.900000    14200.000000
#
#        Coeficiente de Gini        IDH
# count            10.000000  35.000000
# mean             44.110000   0.670914
# std               8.161216   0.146201
# min              33.300000   0.300000
# 25%              37.925000   0.593000
# 50%              41.800000   0.677000
# 75%              50.675000   0.748000
# max              58.700000   0.917000

# %%
opep2000.describe()
# Out:
#        Produção de petróleo (toneladas)  \
# count                      1.200000e+01
# mean                       1.260000e+08
# std                        1.159850e+08
# min                        2.160000e+07
# 25%                        6.015000e+07
# 50%                        1.080000e+08
# 75%                        1.367500e+08
# max                        4.560000e+08
#
#        Reserva acessível (equivalente em toneladas)  \
# count                                  1.200000e+01
# mean                                   9.654000e+09
# std                                    9.964378e+09
# min                                    6.230000e+08
# 25%                                    2.110000e+09
# 50%                                    7.705000e+09
# 75%                                    1.337500e+10
# max                                    3.580000e+10
#
#        % do combustível na exportação de mercadorias  Taxa de câmbio  \
# count                                      10.000000       12.000000
# mean                                       88.960000     2246.680833
# std                                        14.483953     7182.952790
# min                                        49.400000        0.307000
# 25%                                        89.325000        0.638000
# 50%                                        93.000000        3.710000
# 75%                                        96.400000       81.975000
# max                                        99.600000    25000.000000
#
#        Coeficiente de Gini        IDH
# count              2.00000  11.000000
# mean              54.20000   0.683364
# std                3.11127   0.117784
# min               52.00000   0.391000
# 25%               53.10000   0.655000
# 50%               54.20000   0.672000
# 75%               55.30000   0.764000
# max               56.40000   0.809000

# %%
opep2000['IDH'].describe()
# Out:
# count    11.000000
# mean      0.683364
# std       0.117784
# min       0.391000
# 25%       0.655000
# 50%       0.672000
# 75%       0.764000
# max       0.809000
# Name: IDH, dtype: float64

# %%
outros2000['IDH'].describe()
# Out:
# count    35.000000
# mean      0.670914
# std       0.146201
# min       0.300000
# 25%       0.593000
# 50%       0.677000
# 75%       0.748000
# max       0.917000
# Name: IDH, dtype: float64

# %%
faixa = np.arange(1e5,5e8,2e7)

fig = plt.figure(figsize=(15,10))
plt.subplot(231)
plot=opep1990['Produção de petróleo (toneladas)'].plot.hist(bins=faixa,title='HISTOGRAMA produção de petróleo OPEP - 1990', density=True, color='green', alpha=0.5)
plt.ylabel('Densidade')
plt.xlabel('Produção de petróleo (em toneladas)')

plt.subplot(234)
plot=outros1990['Produção de petróleo (toneladas)'].plot.hist(bins=faixa,title='HISTOGRAMA produção de petróleo mundo - 1990', density=True, color='blue', alpha=0.5)
plt.ylabel('Densidade')
plt.xlabel('Produção de petróleo (em toneladas)')


plt.subplot(232)
plot=opep2000['Produção de petróleo (toneladas)'].plot.hist(bins=faixa,title='HISTOGRAMA produção de petróleo OPEP - 2000', density=True, color='green', alpha=0.5)
plt.ylabel('Densidade')
plt.xlabel('Produção de petróleo (em toneladas)')

plt.subplot(235)
plot=outros2000['Produção de petróleo (toneladas)'].plot.hist(bins=faixa,title='HISTOGRAMA produção  de petróleo mundo - 2000', density=True, color='blue', alpha=0.5)
plt.ylabel('Densidade')
plt.xlabel('Produção de petróleo (em toneladas)')

plt.subplot(233)
plot=opep2010['Produção de petróleo (toneladas)'].plot.hist(bins=faixa,title='HISTOGRAMA produção de petróleo OPEP - 2010', density=True, color='green', alpha=0.5)
plt.ylabel('Densidade')
plt.xlabel('Produção de petróleo (em toneladas)')

plt.subplot(236)
plot=outros2010['Produção de petróleo (toneladas)'].plot.hist(bins=faixa,title='HISTOGRAMA produção de petróleo mundo - 2010', density=True, color='blue', alpha=0.5)
plt.ylabel('Densidade')
plt.xlabel('Produção de petróleo (em toneladas)')

plt.tight_layout()
plt.show()

# %%
def reta(dados_x, dados_y, c):    
    a = dados_y.cov(dados_x) / dados_x.var()
    b = dados_y.mean() - a*dados_x.mean()

    print('Ajuste linear entre X3 e X4:')
    print('Coeficiente linear:', b)
    print('Coeficiente angular:', a)
    plt.title('x versus y')
    plt.xlabel('eixo x')
    plt.ylabel('eixo y')

    plt.plot((dados_x.min(), dados_x.max()), (a*dados_x.min()+b, a*dados_x.max()+b), color=c)

    plt.tight_layout()

fig = plt.figure(figsize=(10, 10))
plt.scatter(opep2000['Produção de petróleo (toneladas)'], opep2000['IDH'], c='red')
reta(opep2000['Produção de petróleo (toneladas)'], opep2000['IDH'], "red")
plt.scatter(outros2000['Produção de petróleo (toneladas)'], outros2000['IDH'], c='blue')
reta(outros2000['Produção de petróleo (toneladas)'], outros2000['IDH'], "blue")
reta(result2000['Produção de petróleo (toneladas)'], result2000['IDH'], "g")
plt.title('Produção de petróleo versus IDH em 2000')
plt.xlabel('Produção de petróleo (toneladas)')
#plt.yscale('log')
plt.ylabel('IDH')
# Out:
# Ajuste linear entre X3 e X4:
# Coeficiente linear: 0.6534246838052441
# Coeficiente angular: 2.376107345904146e-10
# Ajuste linear entre X3 e X4:
# Coeficiente linear: 0.6355693308108211
# Coeficiente angular: 6.006143777777398e-10
# Ajuste linear entre X3 e X4:
# Coeficiente linear: 0.6417176091073444
# Coeficiente angular: 4.2337602369266877e-10
# Text(20.80000000000001, 0.5, 'IDH')

# %%
def reta(dados_x, dados_y, c):    
    a = dados_y.cov(dados_x) / dados_x.var()
    b = dados_y.mean() - a*dados_x.mean()

    print('Ajuste linear entre X3 e X4:')
    print('Coeficiente linear:', b)
    print('Coeficiente angular:', a)
    plt.title('x versus y')
    plt.xlabel('eixo x')
    plt.ylabel('eixo y')

    plt.plot((dados_x.min(), dados_x.max()), (a*dados_x.min()+b, a*dados_x.max()+b), color=c)

    plt.tight_layout()

fig = plt.figure(figsize=(10, 10))
plt.scatter(opep2008['Produção de petróleo (toneladas)'], opep2008['Coeficiente de Gini'], c='red')
reta(opep2008['Produção de petróleo (toneladas)'], opep2008['Coeficiente de Gini'], "red")
plt.scatter(outros2008['Produção de petróleo (toneladas)'], outros2008['Coeficiente de Gini'], c='blue')
reta(outros2008['Produção de petróleo (toneladas)'], outros2008['Coeficiente de Gini'], "blue")
reta(result2008['Produção de petróleo (toneladas)'], result2008['Coeficiente de Gini'], "g")
plt.title('Produção de petróleo versus Coeficiente de gini em 2008')
plt.xlabel('Produção de petróleo (toneladas)')
plt.ylabel('Coeficiente de gini')
# Out:
# Ajuste linear entre X3 e X4:
# Coeficiente linear: 48.37043069775158
# Coeficiente angular: -1.4903392294014047e-08
# Ajuste linear entre X3 e X4:
# Coeficiente linear: 46.78120843427719
# Coeficiente angular: -4.539166045196413e-08
# Ajuste linear entre X3 e X4:
# Coeficiente linear: 39.21074764588312
# Coeficiente angular: 7.198660500068776e-09
# Text(20.80000000000001, 0.5, 'Coeficiente de gini')

# %%
def reta(dados_x, dados_y, c):    
    a = dados_y.cov(dados_x) / dados_x.var()
    b = dados_y.mean() - a*dados_x.mean()

    print('Ajuste linear entre X3 e X4:')
    print('Coeficiente linear:', b)
    print('Coeficiente angular:', a)
    plt.title('x versus y')
    plt.xlabel('eixo x')
    plt.ylabel('eixo y')

    plt.plot((dados_x.min(), dados_x.max()), (a*dados_x.min()+b, a*dados_x.max()+b), color=c)

    plt.tight_layout()

fig = plt.figure(figsize=(10, 10))
plt.scatter(opep2000['% do combustível na exportação de mercadorias'], opep2000['IDH'], c='red')
#reta(opep2000['% do combustível na exportação de mercadorias'], opep2000['IDH'], "red")
plt.scatter(outros2000['% do combustível na exportação de mercadorias'], outros2000['IDH'], c='blue')
reta(result2000['% do combustível na exportação de mercadorias'], result2000['IDH'], "G")
plt.title('% do combustível na exportação de mercadorias versus IDH em 2000')
plt.xlabel('% do combustível na exportação de mercadorias')
#plt.yscale('log')
plt.ylabel('IDH')
plt.show()
# Out:
# Ajuste linear entre X3 e X4:
# Coeficiente linear: 0.706215563160363
# Coeficiente angular: -0.0006726496052876365
